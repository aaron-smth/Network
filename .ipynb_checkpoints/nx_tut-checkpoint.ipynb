# %%
import networkx as nx
import matplotlib.pyplot as plt
import collections
from scipy.stats import linregress
import numpy as np

# %%
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (20, 10),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
plt.rcParams.update(params)
plt.style.use('fivethirtyeight')

# %%
def load_data(fname):
    info = {}
    with open(fname, 'rb') as f:
        G = nx.read_edgelist(f)
    info['G'] = G
    degree_seq = sorted([d for n, d in G.degree()], reverse=True)
    degree_arr = np.array(degree_seq)
    info['degree_mean'] = degree_arr.mean()
    info['degree_std'] = degree_arr.std()
    info['degree_count'] = collections.Counter(degree_seq)
    info['degree_correlation'] = nx.degree_pearson_correlation_coefficient(G)
    return info

# %%
def degree_dist(degree_count, fname, **kwargs):
    fig, ax = plt.subplots()
    xdata, ydata = np.fromiter(degree_count.keys(), dtype=float), np.fromiter(degree_count.values(), dtype=float)
    ax.scatter(xdata, ydata, label='raw data')
    trunc = (xdata<200) & (xdata>10)
    xdata_truncate, ydata_truncate = xdata[trunc], ydata[trunc]
    reg = linregress(np.log(xdata_truncate), np.log(ydata_truncate))
    
    fitted_ydata = np.exp(np.log(xdata) * reg.slope + reg.intercept)
    ax.plot(xdata, fitted_ydata, label='fitted line', color='red')
    ax.annotate(f'fitted slope: {reg.slope:.{3}f}', xy=(0.7,0.7), xycoords='axes fraction', fontsize=20)
    ax.annotate(f'mean of degree: {kwargs["mean"]:.{3}f}', xy=(0.7,0.6), xycoords='axes fraction', fontsize=20)
#     ax.annotate(f'std of degree: {kwargs["std"]:.{3}f}', xy=(0.7,0.5), xycoords='axes fraction', fontsize=20)
    
    ax.set(xscale='log', yscale='log', title=f'{fname[:-4]} Network Degree distribution', 
           xlabel='DEGREE k', ylabel='NODES WITH DEGREE k')
    
    ax.legend(fontsize=20)
    plt.xticks(size=20)
    plt.yticks(size=20)
    plt.show(fig)
    fig.savefig(f'deg_dist_{fname[:-4]}.png')

# %%
fname_li = ['facebook_combined.txt', 'p2p-Gnutella04.txt', 'email-Enron.txt']

# %%
for fname in fname_li:
    info = load_data(fname)
    degree_dist(info['degree_count'], fname, mean=info['degree_mean'], std=info['degree_std'])

# %%
def small_world(G, **kwargs):
    name = kwargs['fname'][:-4]
    mean_dist_li = []
    n_samples = 100
    for node in np.random.choice(G.node, size=n_samples):
        dist = nx.single_source_shortest_path_length(G, node).values()
        mean_dist_li.append(sum(dist) / len(dist))
    fig, ax = plt.subplots()
    ax.hist(mean_dist_li, bins='sqrt')
    ax.set(xlabel='average shortest path length to all other nodes', ylabel='frequency', title=f'{name} average path length distribution')
    mean_dist_arr = np.array(mean_dist_li)
    avg, std, max_, min_ = mean_dist_arr.mean(), mean_dist_arr.std(), mean_dist_arr.max(), mean_dist_arr.min()
    ax.annotate(f'number of samples:{n_samples}', xy=(0.75,0.9), xycoords='axes fraction', fontsize=20)
    ax.annotate(f'mean: {avg:.{3}f}, std: {std:.{3}f}', xy=(0.75,0.8), xycoords='axes fraction', fontsize=20)
    ax.annotate(f'max: {max_:.{3}f}, min: {min_:.{3}f}', xy=(0.75,0.7), xycoords='axes fraction', fontsize=20)
    plt.show(fig)
    fig.savefig(f'path_length_{name}.png')

# %%
for fname in fname_li:
    info = load_data(fname)
    small_world(info['G'], fname=fname)

# %%
for fname in fname_li+['cit-HepPh.txt']:
    info = load_data(fname)
    print(f'{fname} degree_correlation: {info["degree_correlation"]:.{3}f}')
# Out:
# facebook_combined.txt degree_correlation: 0.064
# p2p-Gnutella04.txt degree_correlation: -0.013
# email-Enron.txt degree_correlation: -0.111
# cit-HepPh.txt degree_correlation: -0.006

# %%
# for fname in fname_li:
#     info = load_data(fname)
#     nx.write_gexf(info['G'], path=f'./{fname[:-4]}.gexf')

# %%
G = info['G']

# %%
def connected_node_ratio(graph, centers):
    centers = [center for center in centers if graph.has_node(center)]
    nodes = set()
    for center in centers:
        nodes.update(nx.single_source_shortest_path(graph, center, cutoff=4).keys())
    return len(nodes) / graph.number_of_nodes()

def resilience_test(G, random=True):
    graph = G.copy()
    deg_centrality = nx.degree_centrality(graph)
    print('calculating centers')
    centers_tup_all = sorted(deg_centrality.items(), key=lambda tup:tup[1], reverse=True)
    centers_all = [tup[0] for tup in centers_tup_all]
    centers = centers_all[:10]
    
    d_removal_percent = 0.02 * 0.01
    d_removal_n = int(graph.number_of_nodes() * d_removal_percent)
    n_samples = 100
    
    removal_ratio_li = [0.]
    connection_ratio_li = [connected_node_ratio(graph, centers)]
    # 25 * d_removal_percent = total_removal_percent
    print('calculating nodes')
    for i in range(25):
        if random == True:
            choices = graph.nodes()
        else:
            choices = centers_all[:100]
        graph.remove_nodes_from(np.random.choice(choices, size=d_removal_n))
        rate = (i+1) * d_removal_percent
        ratio = connected_node_ratio(graph, centers)
        removal_ratio_li.append(rate)
        connection_ratio_li.append(ratio)
        print(f'removal ratio:{rate}, connection ratio:{ratio}')
    return removal_ratio_li, connection_ratio_li

def plot_resilience(removal_ratio_li, connection_ratio_li, **kwargs):
    fname = kwargs['fname'][:-4]
    fig, ax = plt.subplots()
    ax.scatter(removal_ratio_li, connection_ratio_li, label='raw data')
    ax.set(ylabel='perentage of nodes connected to a few centers',
           xlabel='percentage of nodes removed from the network', title=f'{fname} resilience test (targeting centers)')
    
    xdata, ydata = np.array(removal_ratio_li), np.array(connection_ratio_li)
    reg = linregress(xdata, ydata)
    
    fitted_ydata = xdata * reg.slope + reg.intercept
    ax.plot(xdata, fitted_ydata, label='fitted line', color='red')
    ax.annotate(f'fitted slope: {reg.slope:.{3}f}', xy=(0.7,0.7), xycoords='axes fraction', fontsize=20)
                  
    ax.set(xlim=(xdata.min(), xdata.max()+0.001))
    ax.legend()
    plt.show(fig)
    fig.savefig(f'resilience2_{fname}.png')

# %%
for fname in fname_li:
    info = load_data(fname)
    removal_ratio_li, connection_ratio_li = resilience_test(G, random=False)
    plot_resilience(removal_ratio_li, connection_ratio_li, fname=fname)
# Out:
# calculating centers
# calculating nodes
# removal ratio:0.0002, connection ratio:0.9022515400970398
# removal ratio:0.0004, connection ratio:0.8953624689877041
# removal ratio:0.0006000000000000001, connection ratio:0.8870044172983585
# removal ratio:0.0008, connection ratio:0.8799192734611504
# removal ratio:0.001, connection ratio:0.8686033824331697
# removal ratio:0.0012000000000000001, connection ratio:0.8655808370164239
# removal ratio:0.0014, connection ratio:0.857099978170705
# removal ratio:0.0016, connection ratio:0.8495019784418065
# removal ratio:0.0018000000000000002, connection ratio:0.802587406861541
# removal ratio:0.002, connection ratio:0.795092258980238
# removal ratio:0.0022, connection ratio:0.7915267654846723
# removal ratio:0.0024000000000000002, connection ratio:0.788627429569775
# removal ratio:0.0026000000000000003, connection ratio:0.7839357868297477
# removal ratio:0.0028, connection ratio:0.7821492928520724
# removal ratio:0.003, connection ratio:0.7813515358361774
# removal ratio:0.0032, connection ratio:0.7778445239330476
# removal ratio:0.0034000000000000002, connection ratio:0.7724591775435531
# removal ratio:0.0036000000000000003, connection ratio:0.7724591775435531
# removal ratio:0.0038, connection ratio:0.7619398705660686
# removal ratio:0.004, connection ratio:0.7485389699055109
# removal ratio:0.004200000000000001, connection ratio:0.7466477319277931
# removal ratio:0.0044, connection ratio:0.745131776594292
# removal ratio:0.0046, connection ratio:0.7441962091003441
# removal ratio:0.0048000000000000004, connection ratio:0.7441962091003441
# removal ratio:0.005, connection ratio:0.7381732765213591
# calculating centers
# calculating nodes
# removal ratio:0.0002, connection ratio:0.9002317023306529
# removal ratio:0.0004, connection ratio:0.8878619335841649
# removal ratio:0.0006000000000000001, connection ratio:0.8705789315808132
# removal ratio:0.0008, connection ratio:0.86368843069874
# removal ratio:0.001, connection ratio:0.8555685878726712
# removal ratio:0.0012000000000000001, connection ratio:0.8339153208206024
# removal ratio:0.0014, connection ratio:0.8315553979210433
# removal ratio:0.0016, connection ratio:0.828808425877923
# removal ratio:0.0018000000000000002, connection ratio:0.8252967662709783
# removal ratio:0.002, connection ratio:0.8216527482124338
# removal ratio:0.0022, connection ratio:0.811589060538239
# removal ratio:0.0024000000000000002, connection ratio:0.8101867016049787
# removal ratio:0.0026000000000000003, connection ratio:0.8015123389386329
# removal ratio:0.0028, connection ratio:0.7985475988970487
# removal ratio:0.003, connection ratio:0.7908043466389996
# removal ratio:0.0032, connection ratio:0.7904436860068259
# removal ratio:0.0034000000000000002, connection ratio:0.7893127269748519
# removal ratio:0.0036000000000000003, connection ratio:0.7869801480025123
# removal ratio:0.0038, connection ratio:0.7718397553182774
# removal ratio:0.004, connection ratio:0.7718335244961494
# removal ratio:0.004200000000000001, connection ratio:0.730882674240769
# removal ratio:0.0044, connection ratio:0.729427830124266
# removal ratio:0.0046, connection ratio:0.7245984922976073
# removal ratio:0.0048000000000000004, connection ratio:0.7211417645452062
# removal ratio:0.005, connection ratio:0.7211417645452062
# calculating centers
# calculating nodes
# removal ratio:0.0002, connection ratio:0.9022488755622189
# removal ratio:0.0004, connection ratio:0.8929876220077431
# removal ratio:0.0006000000000000001, connection ratio:0.8860983856893543
# removal ratio:0.0008, connection ratio:0.8708648103199061
# removal ratio:0.001, connection ratio:0.8650919207899187
# removal ratio:0.0012000000000000001, connection ratio:0.8502646079982541
# removal ratio:0.0014, connection ratio:0.8418999290664048
# removal ratio:0.0016, connection ratio:0.8372943327239488
# removal ratio:0.0018000000000000002, connection ratio:0.8337608470228675
# removal ratio:0.002, connection ratio:0.8308225533540745
# removal ratio:0.0022, connection ratio:0.8301083485712726
# removal ratio:0.0024000000000000002, connection ratio:0.8287843222883345
# removal ratio:0.0026000000000000003, connection ratio:0.8253677975816798
# removal ratio:0.0028, connection ratio:0.8249263019980347
# removal ratio:0.003, connection ratio:0.8214997406709798
# removal ratio:0.0032, connection ratio:0.8214997406709798
# removal ratio:0.0034000000000000002, connection ratio:0.8202118366455557
# removal ratio:0.0036000000000000003, connection ratio:0.8168887190127772
# removal ratio:0.0038, connection ratio:0.8104794670161642
# removal ratio:0.004, connection ratio:0.8061820763475507
# removal ratio:0.004200000000000001, connection ratio:0.7957673402512289
# removal ratio:0.0044, connection ratio:0.7927851661705672
# removal ratio:0.0046, connection ratio:0.789572864321608
# removal ratio:0.0048000000000000004, connection ratio:0.789572864321608
# removal ratio:0.005, connection ratio:0.7843447861473754
